# %%
import requests
URL = "https://www.your-move.co.uk/estate-agent/burton-on-trent/find-property-for-sale"

page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-gb" tabindex="-1">
# <head>
#     <meta charset="utf-8" />
# 	<meta name="format-detection" content="telephone=no">
# 	<meta name="viewport" content="width=device-width, initial-scale=1" />
# <style>
# @font-face {
#   font-family: "icons";
#   src: url("/assets/fonts/icons.woff2?3f11267c38243a8a61fd29a97602f65d") format("woff2"), url("/assets/fonts/icons.woff?3f11267c38243a8a61fd29a97602f65d") format("woff");
#   font-weight: normal;
#   font-style: normal;
# }</style><noscript><link rel="stylesheet" type="text/css" href="/assets/css/print.min.108b62d4.css" media="print"></noscript><script nonce="5108fe">var evo_load_callbacks = evo_load_callbacks || []; evo_load_callbacks.push(function() {
#     loadCSS($.noop, [{href: "/assets/css/print.min.108b62d4.css"}]);
# });</script><link rel='preload' href='/assets/fonts/icons.woff2?3f11267c38243a8a61fd29a97602f65d' as='font' type='font/woff2' crossorigin>
# ...

# %%
from bs4 import BeautifulSoup as bs

soup = bs(page.content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en-gb" tabindex="-1">
# <head>
# <meta charset="utf-8"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <style>
# @font-face {
#   font-family: "icons";
#   src: url("/assets/fonts/icons.woff2?3f11267c38243a8a61fd29a97602f65d") format("woff2"), url("/assets/fonts/icons.woff?3f11267c38243a8a61fd29a97602f65d") format("woff");
#   font-weight: normal;
#   font-style: normal;
# }</style><noscript><link href="/assets/css/print.min.108b62d4.css" media="print" rel="stylesheet" type="text/css"/></noscript><script nonce="5108fe">var evo_load_callbacks = evo_load_callbacks || []; evo_load_callbacks.push(function() {
#     loadCSS($.noop, [{href: "/assets/css/print.min.108b62d4.css"}]);
# });</script><link as="font" crossorigin="" href="/assets/fonts/icons.woff2?3f11267c38243a8a61fd29a97602f65d" rel="preload" type="font/woff2"/>
# ...

# %%
results = soup.find(id="property_2100313785")
results
# Out:
# <div class="property-thumbnail" id="property_2100313785">
# <div class="property-thumbnail__images property-thumbnail-images"><div class="property-thumbnail-images__main-container"><a class="" data-analytics-click="event:Property Listings (grid view):CTA:Main Image,event:Property Listings:CTA:Main Image" href="https://www.your-move.co.uk/property/detached-house-for-sale-galloway-road-drakelow-de15-id-bur220425?searchId=b7aff5a523b3cde22a245a128dd7a20f&amp;offset=5"><picture class="">
# <source srcset="https://assets.your-move.co.uk/yourmove_new/property-image/rps_yom-BUR220425/image/BUR220425_08/s.webp?v=28978" type="image/webp"/>
# <source srcset="https://assets.your-move.co.uk/yourmove_new/property-image/rps_yom-BUR220425/image/BUR220425_08/s.jpg?v=33559" type="image/jpg"/>
# ...

# %%
elements = results.find_all("div", class_="property-thumbnail-icon property-thumbnail-icon--beds")
for element in elements:
    print(element.text)
# Out:
# 4

# %%
results
# Out:
# <div class="property-thumbnail" id="property_2100313785">
# <div class="property-thumbnail__images property-thumbnail-images"><div class="property-thumbnail-images__main-container"><a class="" data-analytics-click="event:Property Listings (grid view):CTA:Main Image,event:Property Listings:CTA:Main Image" href="https://www.your-move.co.uk/property/detached-house-for-sale-galloway-road-drakelow-de15-id-bur220425?searchId=b7aff5a523b3cde22a245a128dd7a20f&amp;offset=5"><picture class="">
# <source srcset="https://assets.your-move.co.uk/yourmove_new/property-image/rps_yom-BUR220425/image/BUR220425_08/s.webp?v=28978" type="image/webp"/>
# <source srcset="https://assets.your-move.co.uk/yourmove_new/property-image/rps_yom-BUR220425/image/BUR220425_08/s.jpg?v=33559" type="image/jpg"/>
# ...

# %%
a = re.findall("property_[0-9]{10}", "id=\"property_2100313785\"")

# %%
a
# Out:
# ['property_2100313785']

# %%
import re

#results = soup.findAll('div', id=lambda x: x and x.startswith('property_'))
results = soup.findAll('div', id=re.compile("^property_[0-9]{10}"))

for result in results:
    property_id = re.findall("property_[0-9]{10}", result.prettify())[0]
    price = result.find_all("div", class_="property-thumbnail__price")[0].text
    beds = result.find_all("div", class_="property-thumbnail-icon property-thumbnail-icon--beds")[0].text
    baths = result.find_all("div", class_="property-thumbnail-icon property-thumbnail-icon--baths")[0].text
    living_room = result.find_all("div", class_="property-thumbnail-icon property-thumbnail-icon--receptions")[0].text
    print(property_id)
    print(price.strip())
    print(living_room)
    print(beds)
    print(baths)
    print('')
# Out:
# property_2100240543
# £670,000
# 3
# 5
# 3
#
# property_2100321400
# £575,000
# 2
# 5
# 3
#
# property_2100250834
# £460,000
# 2
# 5
# 3
#
# property_2100321487
# £400,000
# 3
# 4
# 1
#
# property_2100313785
# £365,000
# 2
# 4
# 2
#
# property_2100300597
# £360,000
# 1
# 4
# 2
#
# property_2100312356
# £350,000
# 2
# 4
# 2
#
# property_2100215862
# £330,000
# 1
# 3
# 2
#
# property_2100298202
# £325,000
# 2
# 5
# 2
#
# property_2100295171
# £320,000
# 2
# 4
# 2
#
# property_2100242061
# £295,000
# 2
# 4
# 2
#
# property_2100310069
# £285,000
# 2
# 3
# 2

# %%
URL = "https://www.your-move.co.uk/branches"
page = requests.get(URL)
soup = bs(page.content, "html.parser")
results = soup.findAll('h2', class_="branch-thumbnail__title")
branches = [branch.text for branch in results]
branches
# Out:
# ['Abbey Wood',
#  'Abington',
#  'Andover',
#  'Ashford',
#  'Baildon',
#  'Barnsley',
#  'Basingstoke',
#  'Beccles',
#  'Bedford',
#  'Bedworth',
#  'Beeston',
#  'Bellshill',
#  'Belper',
#  'Bexleyheath',
#  'Blaby',
#  'Blackburn',
#  'Blackheath',
#  'Bognor Regis',
#  'Brighton and Hove',
#  'Broadstairs',
#  'Bromley',
#  'Bromsgrove',
#  'Burton on Trent',
#  'Bury',
#  'Camborne',
#  'Canterbury',
#  'Carlisle',
#  'Castle Bromwich',
#  'Chadwell Heath',
#  'Chapeltown',
#  'Chatham',
#  'Chester-le-Street',
#  'Coalville',
#  'Coatbridge',
#  'Consett',
#  'Cornwall New Homes',
#  'Crawcrook',
#  'Crewe',
#  'Dalgety Bay',
#  'Dalkeith',
#  'Darlington',
#  'Dartford',
#  'Darwen',
#  'Deal',
#  'Denton',
#  'Doncaster',
#  'Dudley',
#  'Dumfries',
#  'Dundee',
#  'Dunfermline',
#  'Dunstable',
#  'Durham',
#  'Duston',
#  'Eastbourne',
#  'Edinburgh',
#  'Egham',
#  'Elgin',
#  'Eltham',
#  'Exmouth',
#  'Falkirk',
#  'Faversham',
#  'Forest Gate',
#  'Gillingham',
# ...

# %%
sale_dictionary = {}

for branch in branches:
    for page in range(1, 11):
        URL = (
            f"https://www.your-move.co.uk/estate-agent/{location}/"
            f"find-property-for-sale/!/page/{page}"
        )
        page = requests.get(URL)
        soup = bs(page.content, "html.parser")
        results = soup.findAll("div", id=lambda x: x and x.startswith('property_'))
        
        for result in results:
            price = result.find_all("div", class_="property-thumbnail__price")
            beds = result.find_all("div", class_="property-thumbnail-icon property-thumbnail-icon--beds")
            baths = result.find_all("div", class_="property-thumbnail-icon property-thumbnail-icon--baths")
            for p, bed, bath in zip(price, beds, baths):
                sale_dictionary.update(
                    {
                        branch: {
                            "price"
                        }
                    }
                )
